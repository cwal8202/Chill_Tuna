# %% [markdown]
# # 경쟁사 가격 데이터 전처리 (prompt-friendly)

# %%
IN_XLSX = r"/mnt/data/동원 경쟁사 제품 가격.xlsx"
OUT_JSONL = r"/mnt/data/competitor_prices_preprocessed.jsonl"
OUT_JSON  = r"/mnt/data/competitor_prices_preprocessed.json"
print("Paths set.")

# %%
# 여기에 위 파이프라인 코드를 그대로 붙여넣거나, 함수화해서 재실행하세요.
